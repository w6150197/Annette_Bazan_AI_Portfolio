# %% [markdown]
# # Lab 01 - Python Data Types & Crash Course - Annette Bazan

# %% [markdown]
# ### Types of Data
# 1. strings (str): texts and characters
# 2. integers (int): whole numbers
# 3. float (float): decimal numbers
# 4. Boolean (bool): the outputs are only True and False
# 5. complex: mixture of numbers and characters

# %% [markdown]
# ### Variables
# - Python objects that act as a container to store data
#
# ##### Naming Rules:
# 1. Cannot start a variable's name with a number
# 2. Cannot have space in a variable's name
# 3. Camel-case: wordApp
# 4. under_score: word_app
# 5. Should be descriptive

# %%
a = "I'm a teacher."
a
# Out:
# "I'm a teacher."

# %%
print(a)
# Out:
# I'm a teacher.

# %%
b = 'I am a student.'

# %%
type(a)
# Out:
# str

# %%
c = 5
c
# Out:
# 5

# %%
type(c)
# Out:
# int

# %%
d = 3.14
d
# Out:
# 3.14

# %%
type(d)
# Out:
# float

# %%
e = 6 != 8
e
# Out:
# True

# %%
f = 3 + 4j
f
# Out:
# (3+4j)

# %%
type(f)
# Out:
# complex

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          str        I'm a teacher.
# b          str        I am a student.
# c          int        5
# d          float      3.14
# e          bool       True
# f          complex    (3+4j)

# %%
# deleting a variable 
del b

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          str        I'm a teacher.
# c          int        5
# d          float      3.14
# e          bool       True
# f          complex    (3+4j)

# %% [markdown]
# ### Operators

# %%
g = 2 * 3
g
# Out:
# 6

# %%
h = 8 - 7
h
# Out:
# 1

# %%
i = 10 / 3
i
# Out:
# 3.3333333333333335

# %%
round(10/3)
# Out:
# 3

# %%
round(6/4)
# Out:
# 2

# %%
round(4.5584, 3)
# Out:
# 4.558

# %%
j = 10 // 3 # this is called floor division: drops the remainder
j
# Out:
# 3

# %%
k = 10 % 3 # this is called the modulus: it displays only the remainder
k
# Out:
# 1

# %%
l = divmod(10, 3) # it displays both the quotient and the remainder 
l
# Out:
# (3, 1)

# %%
help(divmod)
# Out:
# Help on built-in function divmod in module builtins:
#
# divmod(x, y, /)
#     Return the tuple (x//y, x%y).  Invariant: div*y + mod == x.

# %%
m = pow(3,3)
m
# Out:
# 27

# %%
3**3
# Out:
# 27

# %%
isinstance(2.0, float)
# Out:
# True

# %% [markdown]
# ### Conclusion:
# - Add 10 takeaways that you learn from completing this lab.
#
# 1. There are naming rules when it comes to variables that we have to abide by.
# 2. There are 4 Data Structure types: List, Tuple, Set, and Dictionary
# 3. There are 5 Data types: Str, Int, Float, boolean, and Complex
# 4.

# %% [markdown]
# #### End of Lab  01.
